# %% [markdown]
# # Exercise

# %% [raw]
# Try read in at least 3 different datasets from here: https://www.kaggle.com/datasets
# Make sure that the column names are read in correctly. Observe the data types for each column and print out summary of the resulting dataframe.
#
# 1) What do the different parameters mean in read_csv?
# 2) Can you read data in from a hyperlink?
# 3) Can you read in data partially, meaning can you skip some rows and if yes, then how?

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Abalone DataSet

# %%
# Data import

abalone = pd.read_csv("abalone.csv")

# %%
# Having a look on the dataset

abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# Shape of the datset

abalone.shape
# Out:
# (4177, 9)

# %%
# Dataset consiting columns

abalone.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
# Individual variable type of the datasets

abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Rings             4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
#type(abalone)

# %% [markdown]
# # US Drought Dataset

# %%
# Dataset importing 

usdrought = pd.read_csv("dm_export_20000101_20180415.csv")

# %%
# Having a look on the dataset

usdrought.head()
# Out:
#    ReleaseDate AreaOfInterest            None             D0             D1  \
# 0     20180410          TOTAL  204,432,995.85  46,331,775.57  29,478,692.62
# 1     20180403          TOTAL  206,468,222.83  44,568,072.07  30,266,535.24
# 2     20180327          TOTAL  203,228,498.95  47,410,154.16  32,733,805.38
# 3     20180320          TOTAL  203,277,687.54  48,484,822.70  29,381,867.65
# 4     20180313          TOTAL  199,461,984.05  52,059,398.61  29,901,042.06
#
#               D2            D3          D4  ValidStart    ValidEnd  \
# 0  24,519,654.40  6,064,704.49  344,412.98  2018-04-10  2018-04-16
# 1  23,536,636.50  6,207,278.31  125,490.97  2018-04-03  2018-04-09
# 2  21,860,838.76  5,816,713.14  122,225.52  2018-03-27  2018-04-02
# 3  25,367,920.95  4,617,423.56   42,513.51  2018-03-20  2018-03-26
# 4  26,762,410.95  2,944,886.73   42,513.51  2018-03-13  2018-03-19
#
#    StatisticFormatID
# 0                  2
# 1                  2
# 2                  2
# ...

# %%
#Shape of the dataset

usdrought.shape
# Out:
# (954, 11)

# %%
usdrought.columns
# Out:
# Index(['ReleaseDate', 'AreaOfInterest', 'None', 'D0', 'D1', 'D2', 'D3', 'D4',
#        'ValidStart', 'ValidEnd', 'StatisticFormatID'],
#       dtype='object')

# %%
usdrought.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 11 columns):
# ReleaseDate          954 non-null int64
# AreaOfInterest       954 non-null object
# None                 954 non-null object
# D0                   954 non-null object
# D1                   954 non-null object
# D2                   954 non-null object
# D3                   954 non-null object
# D4                   954 non-null object
# ValidStart           954 non-null object
# ValidEnd             954 non-null object
# StatisticFormatID    954 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 82.1+ KB

# %%
#usdrought.describe()

# %% [markdown]
# # Water Conservation Supplier Compliance

# %%
# Dataset import 

water1 = pd.read_csv("water1.csv")
water2 = pd.read_csv("water2.csv")
water3 = pd.read_csv("water3.csv")
water1.head()
# Out:
#   August 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19  \
# 0                                   Anderson City of
# 1                                  Calexico  City of
# 2                                 Cloverdale City of
# 3                                 Escondido  City of
# 4                           Hi-Desert Water District
#
#     2016)
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
water1.shape
# Out:
# (20, 2)

# %%
water1.columns
# Out:
# Index(['August 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19', ' 2016)'], dtype='object')

# %%
water2.head()
# Out:
#   July 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19  \
# 0                                Cloverdale  City of
# 1                                   Lemoore  City of
# 2                               Porterville  City of
# 3                                     Ukiah  City of
#
#     2016)
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN

# %%
water3.head()
# Out:
#                    Supplier Name  Hydrologic Region  \
# 0       California City  City of     South Lahontan
# 1  Yucaipa Valley Water District        South Coast
# 2                Sanger  City of        Tulare Lake
# 3               Adelanto City of     South Lahontan
# 4             Red Bluff  City of   Sacramento River
#
#    State-mandated Conservation Standard - Previous (3/1/2016)  \
# 0                                                28%
# 1                                                34%
# 2                                                26%
# 3                                                16%
# 4                                                33%
#
#    State-mandated Conservation Standard - Current (Effective 6/1/2016)  \
# 0                                                28%
# 1                                                20%
# 2                                                26%
# 3                                                16%
# ...

# %%
water = pd.concat([water1,water2,water3], axis=1, sort=False)

# %%
water.head()
# Out:
#   August 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19  \
# 0                                   Anderson City of
# 1                                  Calexico  City of
# 2                                 Cloverdale City of
# 3                                 Escondido  City of
# 4                           Hi-Desert Water District
#
#     2016)  \
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
#   July 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19  \
# 0                                Cloverdale  City of
# 1                                   Lemoore  City of
# 2                               Porterville  City of
# 3                                     Ukiah  City of
# 4                                                NaN
#
#     2016)                  Supplier Name  Hydrologic Region  \
# 0     NaN       California City  City of     South Lahontan
# ...

# %%
water.columns
# Out:
# Index(['August 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19',
#        ' 2016)',
#        'July 2016 Non-filers (The following suppliers did not submit July 2016 data by September 19',
#        ' 2016)', 'Supplier Name', ' Hydrologic Region',
#        ' State-mandated Conservation Standard - Previous (3/1/2016)',
#        ' State-mandated Conservation Standard - Current (Effective 6/1/2016)',
#        ' Did Supplier Self-certify?',
#        ' Enforceable Cumulative Percent Savings (as compared to 2013) - June 2015-Aug 2016',
#        ' June 2016 to Aug 2016 Self-certified?',
#        ' Applicable Cumulative Savings by Supplier (as compared to 2013)',
#        ' Missed Conservation Standard By', ' Order Status',
#        ' Monthly Savings (as compared to 2013) - Aug 2015',
#        ' Monthly Savings (as compared to 2013) - Aug 2016',
#        ' Estimated Aug 2016 Monthly R-GPCD', ' Total Population Served'],
#       dtype='object')

# %% [markdown]
# # read_csv mean

# %% [raw]
# pd.read_csv means, telling to Pandas to rad the "csv" file which is the dataset store already in the same directory of Python file or from URL.

# %% [markdown]
# # Reading data from URL

# %%
# Abalone datset importing from URL
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"

# %%
abalone_url = pd.read_csv(url)

# %%
abalone_url.head()
# Out:
#    M  0.455  0.365  0.095   0.514  0.2245   0.101   0.15  15
# 0  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 1  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 2  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 3  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7
# 4  I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.120   8

# %% [markdown]
# # Partially reading the dataset

# %%
# Skipping columns or dropping

abalone.drop(["Length","Diameter"], axis=1)
# Out:
#      Sex  Height  Whole weight  Shucked weight  Viscera weight  Shell weight  \
# 0      M   0.095        0.5140          0.2245          0.1010        0.1500
# 1      M   0.090        0.2255          0.0995          0.0485        0.0700
# 2      F   0.135        0.6770          0.2565          0.1415        0.2100
# 3      M   0.125        0.5160          0.2155          0.1140        0.1550
# 4      I   0.080        0.2050          0.0895          0.0395        0.0550
# 5      I   0.095        0.3515          0.1410          0.0775        0.1200
# 6      F   0.150        0.7775          0.2370          0.1415        0.3300
# 7      F   0.125        0.7680          0.2940          0.1495        0.2600
# 8      M   0.125        0.5095          0.2165          0.1125        0.1650
# 9      F   0.150        0.8945          0.3145          0.1510        0.3200
# 10     F   0.140        0.6065          0.1940          0.1475        0.2100
# ...
